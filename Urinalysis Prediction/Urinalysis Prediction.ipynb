# %% [markdown]
# # **Urinalysis Test Dataset**
# Predict if the Urinalysis is positive or negative

# %%
#Import the drive module from Google Colab to mount your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import the pandas library for data manipulation
import pandas as pd

#Read the CSV file from your Google Drive into a pandas DataFrame
dataset = pd.read_csv("/content/drive/MyDrive/urinalysis_tests.csv")
print(dataset)
# Out:
#         Age  Gender         Color   Transparency   Glucose   Protein   pH  \
# 0     76.00  FEMALE  LIGHT YELLOW          CLEAR  NEGATIVE  NEGATIVE  5.0
# 1      9.00    MALE   DARK YELLOW  SLIGHTLY HAZY  NEGATIVE        1+  5.0
# 2     12.00    MALE  LIGHT YELLOW  SLIGHTLY HAZY  NEGATIVE     TRACE  5.0
# 3     77.00    MALE         BROWN         CLOUDY  NEGATIVE        1+  6.0
# 4     29.00  FEMALE        YELLOW           HAZY  NEGATIVE     TRACE  6.0
# ...     ...     ...           ...            ...       ...       ...  ...
# 1431   0.06    MALE        YELLOW          CLEAR  NEGATIVE  NEGATIVE  6.0
# 1432  42.00    MALE        YELLOW          CLEAR  NEGATIVE  NEGATIVE  6.5
# 1433  47.00  FEMALE   DARK YELLOW          CLEAR  NEGATIVE     TRACE  6.0
# 1434  57.00  FEMALE   DARK YELLOW          CLEAR  NEGATIVE     TRACE  5.0
# 1435   3.00    MALE        YELLOW          CLEAR  NEGATIVE  NEGATIVE  6.0
#
#       Specific Gravity    WBC     RBC Epithelial Cells Mucous Threads  \
# 0                1.010  3-Jan     0-2       OCCASIONAL           RARE
# 1                1.030  3-Jan     0-2             RARE            FEW
# 2                1.030    0-3     0-2             RARE            FEW
# 3                1.020  8-May  LOADED             RARE           RARE
# 4                1.025  4-Jan     0-2             RARE           RARE
# ...                ...    ...     ...              ...            ...
# 1431             1.015  2-Jan     0-1             RARE            FEW
# 1432             1.010    0-2     0-2             RARE      NONE SEEN
# 1433             1.030  4-Feb     0-2         MODERATE       MODERATE
# 1434             1.030    0-2     0-2           PLENTY         PLENTY
# 1435             1.020    0-1     0-2             RARE           RARE
#
#      Amorphous Urates    Bacteria Diagnosis
# 0           NONE SEEN  OCCASIONAL  NEGATIVE
# 1                 FEW    MODERATE  NEGATIVE
# 2            MODERATE        RARE  NEGATIVE
# 3           NONE SEEN         FEW  NEGATIVE
# 4           NONE SEEN         FEW  NEGATIVE
# ...               ...         ...       ...
# 1431        NONE SEEN        RARE  NEGATIVE
# 1432        NONE SEEN        RARE  NEGATIVE
# 1433        NONE SEEN        RARE  NEGATIVE
# 1434        NONE SEEN         FEW  NEGATIVE
# 1435        NONE SEEN        RARE  NEGATIVE
#
# [1436 rows x 15 columns]

# %% [markdown]
# # **Label Encoding Categorical Data**

# %%
#Import the LabelEncoder from scikit-learn to convert categorical data into numerical format
from sklearn.preprocessing import LabelEncoder

Le = LabelEncoder()

#Convert all categorical columns to numerical format using LabelEncoder
dataset['Gender'] = Le.fit_transform(dataset['Gender'])
dataset['Color'] = Le.fit_transform(dataset['Color'])
dataset['Transparency'] = Le.fit_transform(dataset['Transparency'])
dataset['Glucose'] = Le.fit_transform(dataset['Glucose'])
dataset['Protein'] = Le.fit_transform(dataset['Protein'])
dataset['WBC'] = Le.fit_transform(dataset['WBC'])
dataset['RBC'] = Le.fit_transform(dataset['RBC'])
dataset['Epithelial Cells'] = Le.fit_transform(dataset['Epithelial Cells'])
dataset['Mucous Threads'] = Le.fit_transform(dataset['Mucous Threads'])
dataset['Amorphous Urates'] = Le.fit_transform(dataset['Amorphous Urates'])
dataset['Bacteria'] = Le.fit_transform(dataset['Bacteria'])

# %% [markdown]
# # **Separating Target Variable and Features**

# %%
#Separate the target variable 'Diagnosis' and the features
Y = dataset['Diagnosis']
X = dataset.drop(['Diagnosis'],axis=1)
X
# Out:
#         Age  Gender  Color  Transparency  Glucose  Protein   pH  \
# 0     76.00       0      4             0        4        3  5.0
# 1      9.00       1      2             3        4        0  5.0
# 2     12.00       1      4             3        4        4  5.0
# 3     77.00       1      1             1        4        0  6.0
# 4     29.00       0      9             2        4        4  6.0
# ...     ...     ...    ...           ...      ...      ...  ...
# 1431   0.06       1      9             0        4        3  6.0
# 1432  42.00       1      9             0        4        3  6.5
# 1433  47.00       0      2             0        4        4  6.0
# 1434  57.00       0      2             0        4        4  5.0
# 1435   3.00       1      9             0        4        3  6.0
#
#       Specific Gravity  WBC  RBC  Epithelial Cells  Mucous Threads  \
# 0                1.010   41    2                 4               5
# 1                1.030   41    2                 6               0
# 2                1.030    2    2                 6               0
# 3                1.020   69   51                 6               5
# 4                1.025   47    2                 6               5
# ...                ...  ...  ...               ...             ...
# 1431             1.015   33    1                 6               0
# 1432             1.010    1    2                 6               2
# 1433             1.030   46    2                 2               1
# 1434             1.030    1    2                 5               4
# 1435             1.020    0    2                 6               5
#
#       Amorphous Urates  Bacteria
# 0                    2         3
# 1                    0         2
# 2                    1         5
# 3                    2         0
# 4                    2         0
# ...                ...       ...
# 1431                 2         5
# 1432                 2         5
# 1433                 2         5
# 1434                 2         0
# 1435                 2         5
#
# [1436 rows x 14 columns]

# %% [markdown]
# # **Splitting and Normalization of data**

# %%
#Import necessary libraries for data preprocessing and model evaluation
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

#Encode the target variable 'Diagnosis' into numerical format
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test= train_test_split(X.values,Y, test_size=0.2, random_state= 42)

#Scale the features using MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # **K-Nearest Neighbour Classifier**

# %%
#Import necessary libraries for visualization and model training
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, roc_curve, auc

#Create a KNN classifier with k=6 neighbors
classifier = KNeighborsClassifier(n_neighbors=6)

#Train the KNN classifier on the training data
classifier.fit(X_train_scaled, Y_train)

#Make predictions on the test data
y_pred = classifier.predict(X_test_scaled)


#Calculate the evaluation metrics for the KNN classifier
knn_accuracy = accuracy_score(Y_test, y_pred)
y_scores = classifier.predict_proba(X_test_scaled)
fpr, tpr, threshold = roc_curve(Y_test, y_scores[:, 1], pos_label=1)
Knn_auc = auc(fpr, tpr)
knn_precision = precision_score(Y_test, y_pred, average='weighted')
knn_recall = recall_score(Y_test, y_pred, average='weighted')
knn_f1 = f1_score(Y_test, y_pred, average='weighted')

#Print the evaluation metrics for the KNN classifier
print(f"K-Nearest Neighbour Classifier Accuracy: {knn_accuracy}")
print(f"K-Nearest Neighbour Classifier AUC Score: {Knn_auc}")
print(f"K-Nearest Neighbour Classifier Precision Score: {knn_precision}")
print(f"K-Nearest Neighbour Classifier Recall Score: {knn_recall}")
print(f"K-Nearest Neighbour Classifier F1 Score: {knn_f1}")

#Create a list of metric names
metrics = ['Accuracy', 'AUC Score', 'Precision', 'Recall', 'F1 Score']

#Create a list of corresponding metric values
#accuracy, auc_score, precision, recall, and f1 are already calculated
values = [knn_accuracy,Knn_auc,knn_precision,knn_recall,knn_f1]

plt.figure(figsize=(10, 6))

#Create a bar plot with the metrics on the x-axis and their corresponding values on the y-axis
#Each bar is colored differently for better visualization
plt.bar(metrics, values, color=['blue', 'red', 'green', 'purple', 'orange'])

plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('K-Nearest Neighbour Classifier Metrics')
#Set the y-axis limits between 0 and 1 to better visualize the scores
plt.ylim(0.0, 1.0)
plt.show()
# Out:
# K-Nearest Neighbour Classifier Accuracy: 0.9340277777777778
# K-Nearest Neighbour Classifier AUC Score: 0.7587686567164178
# K-Nearest Neighbour Classifier Precision Score: 0.938395276809911
# K-Nearest Neighbour Classifier Recall Score: 0.9340277777777778
# K-Nearest Neighbour Classifier F1 Score: 0.9053124553124553

# %% [markdown]
# # **Decision tree learning**

# %%
#Import the DecisionTreeClassifier from the sklearn.tree module
from sklearn import tree

#Create a Decision Tree Classifier with entropy as the criterion and a fixed random state of 42 for reproducibility
Classifier = tree.DecisionTreeClassifier(criterion = 'entropy', random_state=42)

#Train the Decision Tree Classifier on the training data
Classifier = Classifier.fit(X_train_scaled, Y_train)

# Make predictions on the test data
y_pred = Classifier.predict(X_test_scaled)

#Calculate the evaluation metrics for the Decision Tree Classifier
DT_accuracy = accuracy_score(Y_test, y_pred)
DT_auc_score = roc_auc_score(Y_test, y_pred)
DT_precision = precision_score(Y_test, y_pred, average='weighted')
DT_recall = recall_score(Y_test, y_pred, average='weighted')
DT_f1 = f1_score(Y_test, y_pred, average='weighted')

#Print the evaluation metrics for the Decision Tree Classifier
print(f"Decision Tree Accuracy: {DT_accuracy}")
print(f"Decision Tree AUC Score: {DT_auc_score}")
print(f"Decision Tree Precision Score: {DT_precision}")
print(f"Decision Tree Recall Score: {DT_recall}")
print(f"Decision Tree F1 Score: {DT_f1}")

# Create a list of metric names
metrics = ['Accuracy', 'AUC Score', 'Precision', 'Recall', 'F1 Score']

# Create a list of corresponding metric values for the Decision Tree Classifier
values = [DT_accuracy, DT_auc_score, DT_precision, DT_recall, DT_f1]

plt.figure(figsize=(10, 6))

# Create a line plot with the metrics on the x-axis and their corresponding values on the y-axis
# Each point is marked with a circle and connected with a line
plt.plot(metrics, values, marker='o', color='b', linestyle='-')
plt.title('Performance Metrics for Decision Tree Model')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# Decision Tree Accuracy: 0.9444444444444444
# Decision Tree AUC Score: 0.6925373134328358
# Decision Tree Precision Score: 0.936392914653784
# Decision Tree Recall Score: 0.9444444444444444
# Decision Tree F1 Score: 0.9379084967320261

# %%
#Plot the Decision Tree using the plot_tree function from the sklearn.tree module
tree.plot_tree(Classifier)
# Out:
# [Text(0.6069214876033058, 0.9736842105263158, 'x[3] <= 0.125\nentropy = 0.3\nsamples = 1148\nvalue = [1087, 61]'),
#  Text(0.34297520661157027, 0.9210526315789473, 'x[9] <= 0.635\nentropy = 0.148\nsamples = 897\nvalue = [878, 19]'),
#  Text(0.32644628099173556, 0.868421052631579, 'x[5] <= 0.875\nentropy = 0.161\nsamples = 808\nvalue = [789, 19]'),
#  Text(0.18181818181818182, 0.8157894736842105, 'x[13] <= 0.5\nentropy = 0.119\nsamples = 557\nvalue = [548, 9]'),
#  Text(0.12396694214876033, 0.7631578947368421, 'x[11] <= 0.3\nentropy = 0.225\nsamples = 193\nvalue = [186, 7]'),
#  Text(0.10743801652892562, 0.7105263157894737, 'entropy = 0.0\nsamples = 75\nvalue = [75, 0]'),
#  Text(0.14049586776859505, 0.7105263157894737, 'x[8] <= 0.662\nentropy = 0.325\nsamples = 118\nvalue = [111, 7]'),
#  Text(0.12396694214876033, 0.6578947368421053, 'x[9] <= 0.048\nentropy = 0.382\nsamples = 94\nvalue = [87, 7]'),
#  Text(0.10743801652892562, 0.6052631578947368, 'x[2] <= 0.6\nentropy = 0.436\nsamples = 78\nvalue = [71, 7]'),
#  Text(0.06611570247933884, 0.5526315789473685, 'x[13] <= 0.2\nentropy = 0.206\nsamples = 31\nvalue = [30, 1]'),
#  Text(0.049586776859504134, 0.5, 'entropy = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.08264462809917356, 0.5, 'x[0] <= 0.288\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06611570247933884, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09917355371900827, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1487603305785124, 0.5526315789473685, 'x[8] <= 0.007\nentropy = 0.551\nsamples = 47\nvalue = [41, 6]'),
#  Text(0.1322314049586777, 0.5, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.1652892561983471, 0.5, 'x[7] <= 0.3\nentropy = 0.619\nsamples = 39\nvalue = [33, 6]'),
#  Text(0.1322314049586777, 0.4473684210526316, 'x[6] <= 0.583\nentropy = 0.773\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.11570247933884298, 0.39473684210526316, 'x[0] <= 0.619\nentropy = 0.852\nsamples = 18\nvalue = [13, 5]'),
#  Text(0.09917355371900827, 0.34210526315789475, 'x[0] <= 0.587\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.08264462809917356, 0.2894736842105263, 'x[9] <= 0.029\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.03305785123966942, 0.23684210526315788, 'x[10] <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.01652892561983471, 0.18421052631578946, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.049586776859504134, 0.18421052631578946, 'x[8] <= 0.534\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03305785123966942, 0.13157894736842105, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06611570247933884, 0.13157894736842105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1322314049586777, 0.23684210526315788, 'x[8] <= 0.486\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.11570247933884298, 0.18421052631578946, 'x[8] <= 0.216\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.09917355371900827, 0.13157894736842105, 'x[10] <= 0.75\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.08264462809917356, 0.07894736842105263, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.11570247933884298, 0.07894736842105263, 'x[11] <= 0.7\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09917355371900827, 0.02631578947368421, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1322314049586777, 0.02631578947368421, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1322314049586777, 0.13157894736842105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1487603305785124, 0.18421052631578946, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.11570247933884298, 0.2894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1322314049586777, 0.34210526315789475, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1487603305785124, 0.39473684210526316, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.19834710743801653, 0.4473684210526316, 'x[0] <= 0.016\nentropy = 0.323\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.18181818181818182, 0.39473684210526316, 'x[10] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1652892561983471, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19834710743801653, 0.34210526315789475, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.21487603305785125, 0.39473684210526316, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.14049586776859505, 0.6052631578947368, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.15702479338842976, 0.6578947368421053, 'entropy = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.2396694214876033, 0.7631578947368421, 'x[4] <= 0.3\nentropy = 0.049\nsamples = 364\nvalue = [362, 2]'),
#  Text(0.2066115702479339, 0.7105263157894737, 'x[7] <= 0.3\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.19008264462809918, 0.6578947368421053, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2231404958677686, 0.6578947368421053, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2727272727272727, 0.7105263157894737, 'x[8] <= 0.547\nentropy = 0.028\nsamples = 358\nvalue = [357, 1]'),
#  Text(0.256198347107438, 0.6578947368421053, 'entropy = 0.0\nsamples = 300\nvalue = [300, 0]'),
#  Text(0.2892561983471074, 0.6578947368421053, 'x[7] <= 0.5\nentropy = 0.126\nsamples = 58\nvalue = [57, 1]'),
#  Text(0.2727272727272727, 0.6052631578947368, 'entropy = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(0.30578512396694213, 0.6052631578947368, 'x[0] <= 0.07\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.2892561983471074, 0.5526315789473685, 'x[5] <= 0.375\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2727272727272727, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30578512396694213, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32231404958677684, 0.5526315789473685, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.47107438016528924, 0.8157894736842105, 'x[0] <= 0.745\nentropy = 0.242\nsamples = 251\nvalue = [241, 10]'),
#  Text(0.4380165289256198, 0.7631578947368421, 'x[7] <= 0.7\nentropy = 0.191\nsamples = 238\nvalue = [231, 7]'),
#  Text(0.4214876033057851, 0.7105263157894737, 'x[6] <= 0.417\nentropy = 0.289\nsamples = 138\nvalue = [131, 7]'),
#  Text(0.4049586776859504, 0.6578947368421053, 'x[8] <= 0.946\nentropy = 0.401\nsamples = 88\nvalue = [81, 7]'),
#  Text(0.3884297520661157, 0.6052631578947368, 'x[0] <= 0.152\nentropy = 0.362\nsamples = 87\nvalue = [81, 6]'),
#  Text(0.35537190082644626, 0.5526315789473685, 'x[0] <= 0.13\nentropy = 0.535\nsamples = 41\nvalue = [36, 5]'),
#  Text(0.33884297520661155, 0.5, 'x[11] <= 0.3\nentropy = 0.469\nsamples = 40\nvalue = [36, 4]'),
#  Text(0.32231404958677684, 0.4473684210526316, 'x[8] <= 0.588\nentropy = 0.605\nsamples = 27\nvalue = [23, 4]'),
#  Text(0.30578512396694213, 0.39473684210526316, 'x[10] <= 0.5\nentropy = 0.702\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.2727272727272727, 0.34210526315789475, 'x[1] <= 0.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.256198347107438, 0.2894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2892561983471074, 0.2894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.33884297520661155, 0.34210526315789475, 'x[0] <= 0.0\nentropy = 0.523\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.32231404958677684, 0.2894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35537190082644626, 0.2894736842105263, 'x[0] <= 0.06\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.33884297520661155, 0.23684210526315788, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.371900826446281, 0.23684210526315788, 'x[0] <= 0.081\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.35537190082644626, 0.18421052631578946, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3884297520661157, 0.18421052631578946, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.33884297520661155, 0.39473684210526316, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.35537190082644626, 0.4473684210526316, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.371900826446281, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4214876033057851, 0.5526315789473685, 'x[12] <= 0.2\nentropy = 0.151\nsamples = 46\nvalue = [45, 1]'),
#  Text(0.4049586776859504, 0.5, 'x[8] <= 0.736\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3884297520661157, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4214876033057851, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4380165289256198, 0.5, 'entropy = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.4214876033057851, 0.6052631578947368, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4380165289256198, 0.6578947368421053, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.45454545454545453, 0.7105263157894737, 'entropy = 0.0\nsamples = 100\nvalue = [100, 0]'),
#  Text(0.5041322314049587, 0.7631578947368421, 'x[2] <= 0.1\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.48760330578512395, 0.7105263157894737, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5206611570247934, 0.7105263157894737, 'x[9] <= 0.029\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.5041322314049587, 0.6578947368421053, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5371900826446281, 0.6578947368421053, 'x[9] <= 0.587\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.5206611570247934, 0.6052631578947368, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5537190082644629, 0.6052631578947368, 'x[10] <= 0.917\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5371900826446281, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5702479338842975, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.359504132231405, 0.868421052631579, 'entropy = 0.0\nsamples = 89\nvalue = [89, 0]'),
#  Text(0.8708677685950413, 0.9210526315789473, 'x[13] <= 0.3\nentropy = 0.652\nsamples = 251\nvalue = [209, 42]'),
#  Text(0.8543388429752066, 0.868421052631579, 'entropy = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(0.887396694214876, 0.868421052631579, 'x[8] <= 0.98\nentropy = 0.868\nsamples = 145\nvalue = [103, 42]'),
#  Text(0.8078512396694215, 0.8157894736842105, 'x[13] <= 0.9\nentropy = 0.776\nsamples = 131\nvalue = [101, 30]'),
#  Text(0.7913223140495868, 0.7631578947368421, 'x[8] <= 0.615\nentropy = 0.856\nsamples = 107\nvalue = [77, 30]'),
#  Text(0.6818181818181818, 0.7105263157894737, 'x[8] <= 0.149\nentropy = 0.964\nsamples = 67\nvalue = [41, 26]'),
#  Text(0.6363636363636364, 0.6578947368421053, 'x[9] <= 0.029\nentropy = 0.258\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.6198347107438017, 0.6052631578947368, 'x[6] <= 0.333\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6033057851239669, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6363636363636364, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6528925619834711, 0.6052631578947368, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.7272727272727273, 0.6578947368421053, 'x[12] <= 0.2\nentropy = 0.987\nsamples = 44\nvalue = [19, 25]'),
#  Text(0.6859504132231405, 0.6052631578947368, 'x[8] <= 0.568\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.6694214876033058, 0.5526315789473685, 'x[11] <= 0.9\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.6528925619834711, 0.5, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.6859504132231405, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7024793388429752, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.768595041322314, 0.6052631578947368, 'x[13] <= 0.6\nentropy = 0.907\nsamples = 31\nvalue = [10, 21]'),
#  Text(0.7355371900826446, 0.5526315789473685, 'x[7] <= 0.3\nentropy = 0.523\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.71900826446281, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7520661157024794, 0.5, 'x[8] <= 0.203\nentropy = 0.337\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.7355371900826446, 0.4473684210526316, 'x[0] <= 0.266\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.71900826446281, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7520661157024794, 0.39473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.768595041322314, 0.4473684210526316, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.8016528925619835, 0.5526315789473685, 'x[4] <= 0.7\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.7851239669421488, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8181818181818182, 0.5, 'x[8] <= 0.399\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.8016528925619835, 0.4473684210526316, 'x[6] <= 0.417\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.7851239669421488, 0.39473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8181818181818182, 0.39473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8347107438016529, 0.4473684210526316, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9008264462809917, 0.7105263157894737, 'x[7] <= 0.5\nentropy = 0.469\nsamples = 40\nvalue = [36, 4]'),
#  Text(0.8842975206611571, 0.6578947368421053, 'x[0] <= 0.174\nentropy = 0.722\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.8512396694214877, 0.6052631578947368, 'x[10] <= 0.167\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.8347107438016529, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8677685950413223, 0.5526315789473685, 'x[8] <= 0.858\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8512396694214877, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8842975206611571, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9173553719008265, 0.6052631578947368, 'x[6] <= 0.167\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.9008264462809917, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9338842975206612, 0.5526315789473685, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.9173553719008265, 0.6578947368421053, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.8243801652892562, 0.7631578947368421, 'entropy = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.9669421487603306, 0.8157894736842105, 'x[2] <= 0.55\nentropy = 0.592\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.9504132231404959, 0.7631578947368421, 'x[13] <= 0.6\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9338842975206612, 0.7105263157894737, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9669421487603306, 0.7105263157894737, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9834710743801653, 0.7631578947368421, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]')]

# %%
#Import the graphviz library for visualizing the Decision Tree
import graphviz

# Export the Decision Tree in the DOT format using the export_graphviz function
dot_data = tree.export_graphviz(Classifier, out_file=None)

#Create a graphviz Source object from the DOT data
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# # **Neural Network**

# %%
#Import the necessary libraries from TensorFlow and Keras
from tensorflow import keras
from keras import layers,models

#Create a sequential model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)), #Input layer with 64 neurons and ReLU activation
    layers.Dense(64, activation='relu'),  #Hidden layer with 64 neurons and ReLU activation
    layers.Dense(1, activation='sigmoid')]) #Output layer with 1 neuron and sigmoid activation (binary classification)

#Compile the model with Adam optimizer, binary cross-entropy loss, and accuracy metric
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#Train the model with training data, validation split, and specified epochs and batch size
md =model.fit(X_train_scaled, Y_train, validation_split=0.2, epochs=30, batch_size=32)

#Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test_scaled, Y_test)

#Make predictions on the test data
y_pred = model.predict(X_test_scaled)

#Convert probabilities to binary predictions (0 or 1)
y_pred_pre = (model.predict(X_test_scaled) > 0.5).astype("int32")


#Print the evaluation metrics for the Neural Network
print(f"Neural Network Accuracy: {accuracy}")
print(f"Neural Network AUC Score: {roc_auc_score(Y_test, y_pred, average = 'weighted', labels=np.unique(y_pred))}")
print(f"Neural Network Precision Score: {precision_score(Y_test, y_pred_pre, average = 'weighted',labels=np.unique(y_pred_pre))}")
print(f"Neural Network Recall Score: {recall_score(Y_test, y_pred_pre, average = 'weighted')}")
print(f"Neural Network F1 Score: {f1_score(Y_test, y_pred_pre, average = 'weighted', labels=np.unique(y_pred_pre))}")

#Plot the training and validation accuracy over epochs
plt.plot(md.history['accuracy'], label='accuracy')
plt.plot(md.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/30
# 29/29 [==============================] - 1s 9ms/step - loss: 0.3721 - accuracy: 0.9444 - val_loss: 0.2096 - val_accuracy: 0.9522
# Epoch 2/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2186 - accuracy: 0.9455 - val_loss: 0.1924 - val_accuracy: 0.9522
# Epoch 3/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2118 - accuracy: 0.9455 - val_loss: 0.1885 - val_accuracy: 0.9522
# Epoch 4/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9455 - val_loss: 0.1804 - val_accuracy: 0.9522
# Epoch 5/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2007 - accuracy: 0.9455 - val_loss: 0.1766 - val_accuracy: 0.9522
# Epoch 6/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1924 - accuracy: 0.9455 - val_loss: 0.1706 - val_accuracy: 0.9522
# Epoch 7/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1876 - accuracy: 0.9455 - val_loss: 0.1683 - val_accuracy: 0.9522
# Epoch 8/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1831 - accuracy: 0.9455 - val_loss: 0.1642 - val_accuracy: 0.9522
# Epoch 9/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1827 - accuracy: 0.9455 - val_loss: 0.1610 - val_accuracy: 0.9522
# Epoch 10/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1788 - accuracy: 0.9455 - val_loss: 0.1597 - val_accuracy: 0.9522
# Epoch 11/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1781 - accuracy: 0.9455 - val_loss: 0.1650 - val_accuracy: 0.9522
# Epoch 12/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1756 - accuracy: 0.9455 - val_loss: 0.1585 - val_accuracy: 0.9522
# Epoch 13/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9455 - val_loss: 0.1587 - val_accuracy: 0.9522
# Epoch 14/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1712 - accuracy: 0.9455 - val_loss: 0.1552 - val_accuracy: 0.9522
# Epoch 15/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1670 - accuracy: 0.9455 - val_loss: 0.1539 - val_accuracy: 0.9522
# Epoch 16/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1638 - accuracy: 0.9455 - val_loss: 0.1524 - val_accuracy: 0.9522
# Epoch 17/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1612 - accuracy: 0.9466 - val_loss: 0.1512 - val_accuracy: 0.9522
# Epoch 18/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1610 - accuracy: 0.9477 - val_loss: 0.1510 - val_accuracy: 0.9522
# Epoch 19/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9477 - val_loss: 0.1500 - val_accuracy: 0.9522
# Epoch 20/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9477 - val_loss: 0.1479 - val_accuracy: 0.9522
# Epoch 21/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1529 - accuracy: 0.9466 - val_loss: 0.1474 - val_accuracy: 0.9522
# Epoch 22/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9477 - val_loss: 0.1450 - val_accuracy: 0.9522
# Epoch 23/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9488 - val_loss: 0.1444 - val_accuracy: 0.9522
# Epoch 24/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9477 - val_loss: 0.1508 - val_accuracy: 0.9522
# Epoch 25/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1456 - accuracy: 0.9488 - val_loss: 0.1393 - val_accuracy: 0.9522
# Epoch 26/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1448 - accuracy: 0.9466 - val_loss: 0.1432 - val_accuracy: 0.9522
# Epoch 27/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.9510 - val_loss: 0.1443 - val_accuracy: 0.9522
# Epoch 28/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.9510 - val_loss: 0.1388 - val_accuracy: 0.9522
# Epoch 29/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9521 - val_loss: 0.1391 - val_accuracy: 0.9522
# Epoch 30/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9521 - val_loss: 0.1370 - val_accuracy: 0.9522
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9340
# 9/9 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step
# Neural Network Accuracy: 0.9340277910232544
# Neural Network AUC Score: 0.8041044776119403
# Neural Network Precision Score: 0.938395276809911
# Neural Network Recall Score: 0.9340277777777778
# Neural Network F1 Score: 0.9053124553124553

# %% [markdown]
# # **Support vector machine**

# %%
#Import the SVC (Support Vector Classifier) class from sklearn.svm
from sklearn.svm import SVC

#Create an SVC model with a rbf kernel, C=1000 and gamma=0.10000
svm_model = SVC(kernel='rbf', C=1000, gamma=0.10000)

#Train the SVC model on the training data
svm_model.fit(X_train_scaled, Y_train)

#Make predictions on the test data
y_pred = svm_model.predict(X_test_scaled)

#Calculate the evaluation metrics for the SVC model
SVC_accuracy = accuracy_score(Y_test, y_pred)
SVC_auc_score = roc_auc_score(Y_test, y_pred)
SVC_precision = precision_score(Y_test, y_pred, average='weighted', labels=np.unique(y_pred))
SVC_recall = recall_score(Y_test, y_pred, average='weighted')
SVC_f1 = f1_score(Y_test, y_pred, average='weighted', labels=np.unique(y_pred))

#Print the evaluation metrics for the SVC model
print(f"Support vector machine Accuracy: {SVC_accuracy}")
print(f"Support vector machine AUC Score: {SVC_auc_score}")
print(f"Support vector machine Precision Score: {SVC_precision}")
print(f"Support vector machine Recall Score: {SVC_recall}")
print(f"Support vector machine F1 Score: {SVC_f1}")

#Create a list of metric names
metrics = ['Accuracy', 'AUC Score', 'Precision', 'Recall', 'F1 Score']

#Create a list of corresponding metric values for the SVC model
values = [SVC_accuracy, SVC_auc_score, SVC_precision, SVC_recall, SVC_f1]

plt.figure(figsize=(10, 6))

# Create a horizontal bar plot with the metrics on the y-axis and their corresponding values on the x-axis
# Each bar is colored differently for better visualization
plt.barh(metrics, values, color=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0'])
plt.xlabel('Score')
plt.title('Support Vector Machine Classifier Metrics')
plt.xlim(0.0, 1.0)  # Set x-axis limits between 0 and 1
plt.show()
# Out:
# Support vector machine Accuracy: 0.9236111111111112
# Support vector machine AUC Score: 0.6350746268656716
# Support vector machine Precision Score: 0.9127708260919939
# Support vector machine Recall Score: 0.9236111111111112
# Support vector machine F1 Score: 0.917293731760847
